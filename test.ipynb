# %%
import pandas as pd
file_path = 'Attendees -  - 2024-05-15 00_37_55 +0800.csv'  # Replace this with your actual file path
data = pd.read_csv(file_path)

# %%
unique_variants = data['Variant'].value_counts()
total_tickets = data['Variant'].count()
print("Unique Variant Counts:")
print("Total Tickets:", total_tickets)
print(unique_variants)
# Out:
# Unique Variant Counts:
# Total Tickets: 119
# Variant
# Youths (Non-member | 25 years old or below)     68
# Youths (Melo member | 25 years old or below)    43
# Online Pass (Non-member)                         4
# Adults (Non-member)                              2
# Adults (Melo CEOs)                               2
# Name: count, dtype: int64

# %%
for variant in data['Variant'].unique():
    display(data[data['Variant'] == variant][['Surname', 'First Name/Nickname', 'Email', 'Variant', "Company/University:"]])
# Out:
#      Surname First Name/Nickname                          Email  \
# 0      Yeung              Athena   athenayeung523.hku@gmail.com
# 1         Lo            Chi Yuen        lochiwork1213@gmail.com
# 2       Wong           Huen Ting      huentingwong114@gmail.com
# 3        Kan     Jie Sheng/Jason            jasonkan6@gmail.com
# 4        Yao             Shirley            yaoszeyan@gmail.com
# 6        Lam               Ansen         ansenlam2003@gmail.com
# 8     Sharma            Anupriya         apanupriya11@gmail.com
# 9       Chia              Audrey         audreycheuka@gmail.com
# 10      Kwok          Bernadette     bernadettekwok24@gmail.com
# 11       Lam             Vincent       lamchakhim0909@gmail.com
# 12       Kan               Robin          robinkan610@gmail.com
# 13      Chan               Chris          chantnchris@gmail.com
# 14       NaN                 NaN           choyjulius@gmail.com
# 15       NaN                 NaN           choyjulius@gmail.com
# ...
